# %% [markdown]
# <a href="https://colab.research.google.com/github/AHamamd150/Zewail-city/blob/main/Gradiant_decent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # Numerical pyhton library
import matplotlib.pyplot as plt # data visulaization library 
import math # math library
import pandas as pd # data handeling library
plt.style.use('default') #use the seaborn style
from mpl_toolkits import mplot3d # for 3d plot

# %% [markdown]
# # Generate some data

# %%
x=np.random.randint(1,20,500)
y = np.log(x)

# %%
plt.scatter(x,y,alpha=0.1);
plt.xlabel('x',fontsize=15);
plt.ylabel('y',fontsize=15);

# %% [markdown]
# # def the gradient descent function

# %%
def Grad(x,y,lr,it):
  n = len(x)
  B0=B =0
  mse,b0,b=[],[],[]
  for i in range(it):
      y_pred= B0 + B *x  # predicted y value
      MSE= 1/n*sum([error**2 for error in (y-y_pred)]) #mean squared error function
      MB0 = -2/n*sum(y- y_pred) # deffrentiated Bias 
      MB = -2/n*sum(x*(y- y_pred)) # deffrentiated weight 
      B0 = B0 - MB0*lr # Update the bias
      B = B - MB*lr  # Update the weight
      mse.append(MSE)
      b0.append(B0)
      b.append(B)
      #print('Bias= {:.5f}  ,B={:.5f}, MSE= {:.5f}'.format(B0,B,MSE))
  return mse,b0,b

# %% [markdown]
# # Lets calculate the gradient descent for different learning rate values

# %%
mse1,b01,b1=Grad(x,y,0.002,15)
mse2,b02,b2=Grad(x,y,0.006,15)
mse3,b03,b3=Grad(x,y,0.007,15)

# %%
plt.figure(figsize=(12,7))
plt.scatter(x,y,marker='*')
for i in range(15):
  plt.plot(x,(b01[i]+b1[i]*x),'--',label='MSE. {:.3f}'.format(mse1[i]),linewidth=1)
plt.legend(loc='best');

# %%
plt.plot(x,(b01[0]+b1[0]*x),'k--',label='MSE= {:.3f}'.format(mse1[0]));
plt.plot(x,(b01[-1]+b1[-1]*x),'r--',label='MSE= {:.3f}'.format(mse1[-1]));
plt.scatter(x,y,marker='*');
plt.xlabel('x',fontsize=15);
plt.ylabel('y',fontsize=15);
plt.legend(loc='best');

# %%
plt.plot(b2,np.array(mse2)/np.array(mse2).max(),'>-',label='MSE, lr=0.002');
plt.plot(b3,np.array(mse3)/np.array(mse3).max(),'>-',label='MSE, lr=0.007');
plt.plot(b1,np.array(mse1)/np.array(mse1).max(),'>-',label='MSE, lr=0.002');

plt.legend();
plt.yscale('log')

# %% [markdown]
# # Lets create some animation for better visualization

# %%
# !pip install celluloid

# %%
from celluloid import Camera
from IPython.display import HTML

# %%
# %%capture
fig = plt.figure(figsize=(12,7))
fig1= fig.add_subplot(221,projection='3d')
fig2= fig.add_subplot(222)
fig3= fig.add_subplot(223)
fig4= fig.add_subplot(224)
count=[]
camera = Camera(fig)
for i in range(1,100):
    count.append(i)
    mse,b0,b=Grad(x,y,0.007,i)
    mse1,b01,b1=Grad(x,y,0.006,i)
    mse2,b02,b2=Grad(x,y,0.004,i)
    fig1.plot3D(b0,b,mse,'--o',linewidth=0.8,c='r',markersize=3);
    fig1.plot3D(b01,b1,mse1,'--o',linewidth=0.8,c='b',markersize=3);
    fig1.plot3D(b02,b2,mse2,'--o',linewidth=0.8,c='g',markersize=3);
    fig1.grid(linestyle='--',c='k')
    fig1.set_xlabel('Bias', fontsize=20,labelpad=20)
    fig1.set_ylabel('Weight', fontsize=20,labelpad=20,rotation=True)
    pl2=fig2.plot(count,mse,'--o',linewidth=1,c='r',markersize=3)
    pl3=fig2.plot(count,mse1,'--o',linewidth=1,c='b',markersize=3)
    pl3=fig2.plot(count,mse2,'--o',linewidth=1,c='g',markersize=3)
    fig2.grid(linestyle='--',c='k')
    fig2.set_xlabel('Iteration', fontsize=20)
    fig2.legend(['MSE(lr=0.007)= {:.3f}'.format(mse[-1]),'MSE(lr=0.006)= {:.3f}'.format(mse1[-1]),'MSE(lr=0.004)= {:.3f}'.format(mse2[-1])])
    fig1.legend(['MSE(lr=0.007)= {:.3f}'.format(mse[-1]),'MSE(lr=0.006)= {:.3f}'.format(mse1[-1]),'MSE(lr=0.004)= {:.3f}'.format(mse2[-1])])
    pl3=fig3.plot(x,(b0[-1]+b[-1]*x),'--',linewidth=2,c='r')
    pl4=fig3.plot(x,(b02[-1]+b2[-1]*x),'--',linewidth=2,c='g')
    fig3.scatter(x,y,marker='o',c='b',s=20,alpha=0.4)
    fig3.grid(linestyle='--',c='k')
    fig3.set_xlabel('X', fontsize=20)
    fig3.set_ylabel('Y', fontsize=20)
    fig3.legend(['MSE(lr=0.007)= {:.3f}'.format(mse[-1]),'MSE(lr=0.004)= {:.3f}'.format(mse2[-1])])
    pl5=fig4.plot(count,mse,'--o',linewidth=1,c='r',markersize=3)
    pl6=fig4.plot(count,mse2,'--o',linewidth=1,c='g',markersize=3)
    fig4.grid(linestyle='--',c='k')
    fig4.set_xlabel('Iteration', fontsize=20)
    fig4.set_ylabel('MSE', fontsize=20)
    fig4.legend(['MSE(lr=0.007)= {:.3f}'.format(mse[-1]),'MSE(lr=0.004)= {:.3f}'.format(mse2[-1])])
    plt.tight_layout()

    camera.snap()
animation = camera.animate()
anmi2 = HTML(animation.to_html5_video())

# %%
anmi2
# Out:
# <video width="1200" height="700" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
fig= plt.figure(figsize=(12,7))
ax = plt.axes(projection='3d');
ax.plot3D(b02,b2,mse2,'-->',label='MSE with lr = 0.006');
#ax.plot3D(b01,b1,mse1,linewidth=1);
ax.plot3D(b03,b3,mse3,'-->',label='MSE with lr = 0.007');
plt.xlabel('Bias');
plt.ylabel('Weight');
plt.legend(loc='best');

# %% [markdown]
# # Binary data sets

# %%
def sigmoid(a,b,x):
  l=a+b*x
  return 1/(1+np.exp(-l))

# %%
X = np.array([-10,-8,-5.5,-1.1,-1,0.5,8,6.2,8.5,9,10])
Y =np.array([0.01,0.02,0.05,0.01,0.01,0.9,0.98,0.9,1,1,0.9])

# %%
plt.scatter(X,Y,marker='*');
plt.xlabel('x');
plt.ylabel('y');

# %%
MSE1,B01,B1,SE1=Grad(X,Y,0.002,50)
MSE2,B02,B2,SE2=Grad(X,Y,0.006,50)
MSE3,B03,B3,SE3=Grad(X,Y,0.007,50)

# %%
plt.plot(X,(B01[-1]+B1[-1]*X),'--',label='Linear');
plt.plot(X,sigmoid(0,10,X),'--',label='Sigmoid');
plt.scatter(X,Y,marker='*',c='r');
plt.xlabel('x',fontsize=15);
plt.ylabel('y',fontsize=15);
plt.legend(loc='best');

# %%
def Grad_Logestic(x,y,lr,it):
  n = len(x)
  B0=B =0
  Cost,b0,b=[],[],[]
  for i in range(it):
      y_hat= sigmoid(B0 , B ,x) 
      cost= -1/n*sum([error for error in (y*np.log(y_hat)+(1-y)*np.log(1-y_hat))])
      
      MB0 = -2/n*sum(y- y_hat)
      MB = -2/n*sum(x*(y- y_hat))
      B0 = B0 - MB0*lr
      B = B - MB*lr
      Cost.append(cost)  
      b0.append(B0)
      b.append(B)
      #print('Bias= {:.5f}  ,B={:.5f}, MSE= {:.5f}'.format(B0,B,cost))
  return Cost,b0,b

# %%
cost_log1,theta01,theta1=Grad_Logestic(X,Y,0.01,10)
cost_log2,theta02,theta2=Grad_Logestic(X,Y,0.1,10)
cost_log3,theta03,theta3=Grad_Logestic(X,Y,0.6,10)

# %%
#plt.plot(X,(B01[-1]+B1[-1]*X),'--',label='Linear');
plt.plot(X,sigmoid(theta01[-1],theta1[-1],X),'--',label='LogLoss={:.3f}, lr=0.01'.format(cost_log1[-1]));
plt.plot(X,sigmoid(theta02[-1],theta2[-1],X),'--',label='LogLoss={:.3f}, lr=0.1'.format(cost_log2[-1]));
plt.plot(X,sigmoid(theta03[-1],theta3[-1],X),'--',label='LogLoss={:.3f}, lr=0.6'.format(cost_log3[-1]));

plt.scatter(X,Y,marker='*',c='k',s=70);
plt.xlabel('x',fontsize=15);
plt.ylabel('y',fontsize=15);
plt.legend(loc='best');

# %% [markdown]
# #Antoher example
# Based on https://www.tensorflow.org/tutorials/keras/regression

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'
column_names = ['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
                'Acceleration', 'Model Year', 'Origin']

raw_dataset = pd.read_csv(url, names=column_names,
                          na_values='?', comment='\t',
                          sep=' ', skipinitialspace=True)

# %%
import tensorflow as tf
import keras

# %%
dataset = raw_dataset.copy()
dataset = dataset.dropna()

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %%
sns.pairplot(train_dataset[['MPG', 'Cylinders', 'Displacement', 'Weight']], diag_kind='kde');

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('MPG')
test_labels = test_features.pop('MPG')

# %%
horsepower = np.array(train_features['Horsepower'])
horsepower_normalizer = layers.Normalization(input_shape=[1,], axis=None)
horsepower_normalizer.adapt(horsepower)

# %%
model = tf.keras.Sequential([
    horsepower_normalizer,
    layers.Dense(units=1)
])

# %%
model.compile(
    optimizer=tf.optimizers.SGD(learning_rate=0.1),
    loss='MSE')

# %%
history = model.fit(
    train_features['Horsepower'],
    train_labels,
    epochs=100,   
    verbose=1,
    validation_split = 0.2)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 1s 66ms/step - loss: 230.2802 - val_loss: 44.7723
# Epoch 2/100
# 8/8 [==============================] - 0s 12ms/step - loss: 31.3098 - val_loss: 25.1503
# Epoch 3/100
# 8/8 [==============================] - 0s 8ms/step - loss: 25.2641 - val_loss: 23.7789
# Epoch 4/100
# 8/8 [==============================] - 0s 10ms/step - loss: 25.1182 - val_loss: 24.0669
# Epoch 5/100
# 8/8 [==============================] - 0s 16ms/step - loss: 25.2079 - val_loss: 23.8942
# Epoch 6/100
# 8/8 [==============================] - 0s 10ms/step - loss: 25.1231 - val_loss: 24.1107
# Epoch 7/100
# 8/8 [==============================] - 0s 15ms/step - loss: 25.2975 - val_loss: 24.0840
# Epoch 8/100
# 8/8 [==============================] - 0s 23ms/step - loss: 25.1587 - val_loss: 23.8546
# Epoch 9/100
# 8/8 [==============================] - 0s 15ms/step - loss: 25.3223 - val_loss: 23.9741
# Epoch 10/100
# ...

# %%
hist = pd.DataFrame(history.history)
plt.plot(history.history['loss'], label='loss');
plt.plot(history.history['val_loss'], label='val_loss');
plt.legend();
plt.yscale('log');
plt.xlabel('epoch');

# %%
x = tf.linspace(30.0, 230, 251)
y = model.predict(x);
plt.scatter(train_features['Horsepower'], train_labels, label='Data',alpha=0.5)
plt.plot(x, y,'k--',  label='Predictions');
plt.xlabel('Hoursepower');
plt.ylabel('MPG');
plt.legend();

# %% [markdown]
# # Fit with DNN model

# %%
model_DNN = keras.Sequential([
      horsepower_normalizer,
      layers.Dense(64, activation='sigmoid'),
      layers.Dense(64, activation='sigmoid'),
      layers.Dense(1)
  ])

model_DNN.compile(loss='mse',
                optimizer=tf.keras.optimizers.SGD(0.01))

# %%
history_DNN = model_DNN.fit(
    train_features['Horsepower'],
    train_labels,
    epochs=100,
    verbose=1,
    validation_split = 0.2)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 1s 50ms/step - loss: 147.4393 - val_loss: 58.3827
# Epoch 2/100
# 8/8 [==============================] - 0s 13ms/step - loss: 55.9492 - val_loss: 57.7778
# Epoch 3/100
# 8/8 [==============================] - 0s 11ms/step - loss: 54.2009 - val_loss: 52.8762
# Epoch 4/100
# 8/8 [==============================] - 0s 11ms/step - loss: 50.9605 - val_loss: 50.6603
# Epoch 5/100
# 8/8 [==============================] - 0s 11ms/step - loss: 49.5911 - val_loss: 46.6116
# Epoch 6/100
# 8/8 [==============================] - 0s 11ms/step - loss: 43.1020 - val_loss: 39.3075
# Epoch 7/100
# 8/8 [==============================] - 0s 14ms/step - loss: 38.5775 - val_loss: 35.3740
# Epoch 8/100
# 8/8 [==============================] - 0s 9ms/step - loss: 33.9913 - val_loss: 31.1063
# Epoch 9/100
# 8/8 [==============================] - 0s 11ms/step - loss: 31.2613 - val_loss: 28.0986
# Epoch 10/100
# ...

# %%
hist = pd.DataFrame(history_DNN.history)
plt.plot(history.history['loss'], label='loss');
plt.plot(history.history['val_loss'], label='val_loss');
plt.legend();
plt.yscale('log')

# %%
x = tf.linspace(30, 230, 251)
y = model_DNN.predict(x);
plt.scatter(train_features['Horsepower'], train_labels, label='Data',alpha=0.5)
plt.plot(x, y,'k--',  label='Predictions');
plt.xlabel('Hoursepower');
plt.ylabel('MPG');
plt.legend();
